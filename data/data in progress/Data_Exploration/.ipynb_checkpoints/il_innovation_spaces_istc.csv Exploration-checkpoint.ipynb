# %%
# %pylab inline
import psycopg2 
import os 
import pandas as pd
import numpy as np

pd.options.display.max_columns = 100
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
inn_spa = pd.read_csv('../il_innovation_spaces_istc.csv')

# %%
inn_spa.head()
# Out:
#    id mc_account_id approved                          name  \
# 0   1           NaN       No     Abundant Venture Partners
# 1   2           NaN       No    Adams Street Partners, LLC
# 2   3           NaN       No  Anderson Pacific Corporation
# 3   4           NaN       No         Apex Venture Partners
# 4   5           NaN       No         ARCH Venture Partners
#
#                      logo_image hidden email                     address  \
# 0          filebin/avp-logo.png     No   NaN  4043 North Ravenswood Ave.
# 1      filebin/adams_street.jpg     No   NaN      One North Wacker Drive
# 2  filebin/anderson_pacific.png     No   NaN                   NBC Tower
# 3         filebin/apex_logo.gif     No   NaN  225 West Washington Street
# 4      filebin/archlogo_web.gif     No   NaN         8725 W. Higgins Rd.
#
#                      address2     city  state_id         zip        created  \
# 0                         NaN  Chicago        13       60613  5/14/13 14:33
# ...

# %%
inn_spa.shape
# Out:
# (663, 47)

# %%
inn_spa.dtypes
# Out:
# id                                     int64
# mc_account_id                         object
# approved                              object
# name                                  object
# logo_image                            object
# hidden                                object
# email                                 object
# address                               object
# address2                              object
# city                                  object
# state_id                               int64
# zip                                   object
# created                               object
# updated                               object
# deleted_date                          object
# user_access_id                         int64
# resource_name                         object
# suite                                 object
# lat                                  float64
# lng                                  float64
# contact_name                          object
# ...

# %%
inn_spa.columns
# Out:
# Index([u'id', u'mc_account_id', u'approved', u'name', u'logo_image', u'hidden', u'email', u'address', u'address2', u'city', u'state_id', u'zip', u'created', u'updated', u'deleted_date', u'user_access_id', u'resource_name', u'suite', u'lat', u'lng', u'contact_name', u'contact_phone', u'website', u'youtube_video_url', u'html_description', u'short_desc', u'mc_account_listings_resources_ids', u'mc_account_listings_sectors_ids', u'additional_institutions', u'institution_name', u'state', u'online_only', u'region_facet', u'funding_facet', u'physical_space_facet', u'facilities_facet', u'nonprofit_facet', u'professional_services_facet', u'other_facet', u'sectors_facet', u'all_sectors', u'additional_info', u'template_file', u'css_file', u'meta_description', u'meta_title', u'meta_keywords'], dtype='object')

# %%
#categorical summaries
for c in [u'id', u'mc_account_id', u'approved', u'name', u'logo_image',\
          u'hidden', u'email', u'address', u'address2', u'city', u'state_id',\
          u'zip', u'created', u'updated', u'deleted_date', u'user_access_id',\
          u'resource_name', u'suite', u'lat', u'lng', u'contact_name', u'contact_phone',\
          u'website', u'youtube_video_url', u'html_description', u'short_desc',\
          u'mc_account_listings_resources_ids', u'mc_account_listings_sectors_ids',\
          u'additional_institutions', u'institution_name', u'state', u'online_only',\
          u'region_facet', u'funding_facet', u'physical_space_facet', u'facilities_facet',\
          u'nonprofit_facet', u'professional_services_facet', u'other_facet', u'sectors_facet',\
          u'all_sectors', u'additional_info', u'template_file', u'css_file', u'meta_description',
          u'meta_title', u'meta_keywords']:
    print c
    print pd.value_counts(inn_spa[c])
    print
# Out:
# id
# 758    1
# 234    1
# 232    1
# 231    1
# 230    1
# 229    1
# 228    1
# 227    1
# 226    1
# 225    1
# 223    1
# 222    1
# 221    1
# 219    1
# 218    1
# ...
# 527    1
# 526    1
# 525    1
# 524    1
# 523    1
# 521    1
# 512    1
# 520    1
# 519    1
# 518    1
# 517    1
# 515    1
# 514    1
# 513    1
# 1      1
# Length: 663, dtype: int64
#
# mc_account_id
# fb906cbd857d72ef4874cd6b72d3d5d7871c0400    12
# 7f9d88a8c77654b27559e941f22fb9170e8104f0     4
# d8d3e14cd44eed658f69e85aa12ae9fd5aa444d9     2
# 76428e9670e5a1a00f2de2b6210d8a8ea40542ea     2
# 4229bc69d4e05e5c0463da26ac09f2428afbf50a     2
# f71b6d3ca8553b51f68f8f495e688310a69d1186     2
# 42acd81147433ce3bb42eedf245525c758a1edf3     2
# e03a67042c97242572207edeefc51e6d377c845b     2
# 59fd482938191c06dafaf63ccbccdee9d5068097     1
# dc7a20d0321cc15c6687dcb846746e6e17c616c2     1
# 3ccdd09af601f45f3e41b6ec5ccb6dac12edc7f0     1
# 15f22c0c82003aaf9c7c6410f632660671e9c621     1
# ...
