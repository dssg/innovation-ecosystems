# %%
# %pylab inline
import psycopg2 
import os 
import pandas as pd
import numpy as np

pd.options.display.max_columns = 100
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cb = pd.read_csv('../CrunchBase_chicago.csv')

# %%
cb.shape
# Out:
# (1212, 15)

# %%
cb.head()
# Out:
#   companies.name companies.category_code            companies.description  \
# 0       20spokes              consulting       Chicago Development Agency
# 1           360i             advertising         digital marketing agency
# 2      37signals                software  Frustration-free web-based apps
# 3    3oclockclub             advertising         multi deal a day website
# 4       5Degrees                     NaN                              NaN
#
#    companies.founded_year  companies.number_of_employees  \
# 0                    2012                              2
# 1                    1998                            425
# 2                    1999                             20
# 3                    2009                             14
# 4                     NaN                            NaN
#
#   companies.total_money_raised     city     description  \
# 0                           $0  Chicago          Office
# 1                           $0  Chicago  Chicago Office
# ...

# %%
cb.dtypes
# Out:
# companies.name                    object
# companies.category_code           object
# companies.description             object
# companies.founded_year           float64
# companies.number_of_employees    float64
# companies.total_money_raised      object
# city                              object
# description                       object
# address1                          object
# address2                          object
# longitude                        float64
# country_code                      object
# latitude                         float64
# state_code                        object
# zip_code                          object
# dtype: object

# %%
cb.columns
# Out:
# Index([u'companies.name', u'companies.category_code', u'companies.description', u'companies.founded_year', u'companies.number_of_employees', u'companies.total_money_raised', u'city', u'description', u'address1', u'address2', u'longitude', u'country_code', u'latitude', u'state_code', u'zip_code'], dtype='object')

# %%
#categorical summaries
for c in [u'companies.name', u'companies.category_code', u'companies.description',\
          u'companies.founded_year', u'companies.number_of_employees',\
          u'companies.total_money_raised', u'city', u'description', u'address1',\
          u'address2', u'longitude', u'country_code', u'latitude', u'state_code', u'zip_code']:
    print c
    print pd.value_counts(cb[c])
    print
# Out:
# companies.name
# Lotame                           3
# ePageCity                        2
# Rent Here Realty                 2
# FieldAware                       2
# Inforama                         2
# Atlantic Metro Communications    2
# First Options of Chicago         2
# Trading Advantage                2
# CMMS Data Group                  2
# Lightology                       2
# American Kidz Academy            2
# Fuzzy Math                       2
# ETF Database                     1
# Academic Capital Exchange        1
# Project Wingman                  1
# ...
# quadrantONE                      1
# Peckish Snacks                   1
# iProspect                        1
# OANDA                            1
# HaveDeals                        1
# Youth Centers of Israel, Inc.    1
# SharkZoo                         1
# ClassConnect                     1
# Rise Interactive                 1
# IGN Entertainment                1
# Garage Door Chicago              1
# ...
